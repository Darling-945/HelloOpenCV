# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data.csv')

# %%
data
# Out:
#         x    y  type
# 0     116   53     3
# 1     109  108     1
# 2     117  105     1
# 3     114   41     3
# 4      76   92     2
# ...   ...  ...   ...
# 5785  141   48     3
# 5786  141   57     3
# 5787  125   57     3
# 5788   71   84     2
# 5789  179   48     5
#
# [5790 rows x 3 columns]

# %%
data['type'].value_counts()
# Out:
# 3     3629
# 2     1260
# 1      460
# 0      255
# 5      170
# 9        8
# 6        6
# 14       2
# Name: type, dtype: int64

# %%
plt.figure(figsize=(10,10))
plt.scatter(data.x,data.y,s=10,c=data.type,cmap='Set2')
plt.show()

# %%
plt.savefig('./scatter.jpg')
